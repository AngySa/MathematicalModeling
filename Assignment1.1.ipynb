# %% [markdown]
# # Assignment 1.1
#
# In this assignment, you will work on Linear Programming problems. You will be given different modeling exercises. For each exercise, you need to:
#
# 1. **Model the problem**: Write the mathematical formulation of the Linear Programming problem in markdown.
# 2. **Solve the problem using PULP**: Implement the model in Python using the PULP library and solve it.
# 3. **Validate the result**: Verify the solution obtained from PULP and ensure it satisfies all the constraints of the problem.

# %% [markdown]
# ## Student Data
#
# - **Student Name**: ...
# - **Student ID**: ...

# %% [markdown]
# ## Exercise 1
#
# ### Problem Statement
#
# A specialty food manufacturer produces two premium products: P1, an organic protein snack bar, and P2, a high-energy granola mix. Both products are profitable and popular among health-conscious consumers, but they compete for limited production resources.
#
# As the company's operations analyst, you have been tasked with developing an optimal weekly production plan. The objective is to maximize total profit while respecting the available production time and ingredient supplies.
#
#
#
# #### Data:
#
# - Profit from each unit of Product P1: $80
# - Profit from each unit of Product P2: $60
# - Production time required per unit of P1: 2 units
# - Production time required per unit of P2: 1 unit
# - Premium ingredients required per unit of P1: 1 unit
# - Premium ingredients required per unit of P2: 2 units
# - Total Production time available: 100 units
# - Total Premium Ingredients available: 80 units

# %% [markdown]
# ### Model
#
# ```python
# # Your Model Here (Decision Variables, Objective, Constraints)
# ```

# %% [markdown]
# ### Implementation

# %%
# Your Code Here

# %% [markdown]
# ### Solution
#
# <span style="color:green"> Your Solution Validation and Your Solution Analysis Here

# %% [markdown]
# ## Exercise 2
#
# ### Problem Statement
#
# A company produces two eco-friendly products: Product A, a premium reusable water bottle, and Product B, a smart insulated travel mug. Demand for both products is strong, but the company faces constraints on skilled labor and sustainably sourced raw materials.
#
# As the operations analyst, you have been asked to develop a production plan for the upcoming month. Management wants to maximize total profit while ensuring that production remains within the available resource limits.
#
#
#
# #### Data:
#
# - Profit from each unit of Product A: $100
# - Profit from each unit of Product B: $120
# - Skilled labor hours required per unit of A: 3 hours
# - Skilled labor hours required per unit of B: 2 hours
# - Sustainable material required per unit of A: 4 units
# - Sustainable material required per unit of B: 5 units
# - Total skilled labor available: 180 hours
# - Total sustainable material available: 200 units

# %% [markdown]
# ### Model
#
# <span style="color:green"> Your Model Here (Decision Variables, Objective, Constraints)

# %% [markdown]
# ### Implementation

# %%
# Your Code Here

# %% [markdown]
# ### Solution
#
# <span style="color:green"> Your Solution Validation and Your Solution Analysis Here

# %% [markdown]
# ## Exercise 3
#
# ### Problem Statement
#
# The Student Sustainability Committee at UANL is organizing a three-day Sustainable Food Festival. The objective is to offer attractive food options to students while generating as much money as possible for future sustainability projects.
# The committee has identified three types of meals that can be prepared: vegetarian bowls, vegan bowls, and local sourced meals
# Each option uses different amounts of budget, kitchen time, ingredients, and preparation capacity, and each generates a different contribution to the sustainability fund.
#
# The committee has a maximum food budget of $4,800.
#
# The ingredient costs per meal are:
#
# | Meal             | Cost per meal |
# |------------------|---------------|
# | Vegetarian       | $7            |
# | Vegan            | $9            |
# | Locally sourced  | $11           |
#
# Different meals require different amounts of preparation time:
#
# | Meal             | Time (min)|
# |------------------|---------------|
# | Vegetarian       | 4            |
# | Vegan            | 5            |
# | Locally sourced  | 7           |
#
#
# The kitchen has at most 3,300 minutes of available preparation time.
# The university wants the festival to promote sustainable eating. The committee therefore requires at least 150 vegan meals.
#
# At least 25% of all meals must use locally sourced ingredients.
#
# The organizers do not want the festival menu to become excessively dominated by vegetarian meals. They require that the number of vegetarian meals be no more than 1.5 times the number of vegan meals.
# The supplier providing certain fresh ingredients can supply enough ingredients for at most 1,200 units of a combination used in vegetarian and locally sourced meals.
# Each vegetarian meal uses 3 units of this resource, while each locally sourced meal uses 4 units.
#
# The sustainability committee estimates the contribution to the sustainability fund generated by each meal as follows:
# | Meal             | Contribution per meal |
# |------------------|---------------|
# | Vegetarian       | $12           |
# | Vegan            | $16            |
# | Locally sourced  | $20           |
#
# The committee wants to maximize the total contribution to the sustainability fund.

# %% [markdown]
# ### Model
#
# <span style="color:green"> Your Model Here (Decision Variables, Objective, Constraints)

# %% [markdown]
# ### Implementation

# %%
# Your Code Here

# %% [markdown]
# ### Solution
#
# <span style="color:green"> Your Solution Validation and Your Solution Analysis Here
